# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2019 until today.

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^DJI', '^GSPC', '^IXIC']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='2019-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                     ^DJI        ^GSPC        ^IXIC
# Date
# 2018-12-31  23327.460938  2506.850098  6635.279785
# 2019-01-02  23346.240234  2510.030029  6665.939941
# 2019-01-03  22686.220703  2447.889893  6463.500000
# 2019-01-04  23433.160156  2531.939941  6738.859863
# 2019-01-07  23531.349609  2549.689941  6823.470215

# %%
ind_data.tail()
# Out:
#                     ^DJI        ^GSPC         ^IXIC
# Date
# 2022-08-03  32812.500000  4155.169922  12668.160156
# 2022-08-04  32726.820312  4151.939941  12720.580078
# 2022-08-05  32803.468750  4145.189941  12657.549805
# 2022-08-08  32832.539062  4140.060059  12644.459961
# 2022-08-09  32774.410156  4122.470215  12493.929688

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %%
# calculating rate of return of major indices in USA
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                 ^DJI     ^GSPC     ^IXIC     ^NSEI  000001.SS
# Date
# 2022-08-03  0.012851  0.015638  0.025865  0.002462  -0.007093
# 2022-08-04 -0.002611 -0.000777  0.004138 -0.000354   0.008019
# 2022-08-05  0.002342 -0.001626 -0.004955  0.000892   0.011913
# 2022-08-08  0.000886 -0.001238 -0.001034  0.007334   0.003068
# 2022-08-09 -0.001770 -0.004249 -0.011905       NaN   0.003244

# %% [markdown]
# Estimate the average annual return of each index.

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^DJI         0.119771
# ^GSPC        0.162788
# ^IXIC        0.208816
# ^NSEI        0.190319
# 000001.SS    0.109451
# dtype: float64

# %% [markdown]
# Observations:
#
# COVID pandemic has adversely effected the growth in the stockmarkets in US as
# we can see a steep fall in stock prices which has picked up and is back to naormal currently.
